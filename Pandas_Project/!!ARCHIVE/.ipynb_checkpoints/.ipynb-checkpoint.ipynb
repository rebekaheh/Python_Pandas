# %%
# Dependencies
import pandas as pd

# %%
# load CSV
file = 'Resources/2016-FCC-New-Coders-Survey-Data.csv'

# %%
# Read with pandas
coders_df = pd.read_csv(r"C:\Users\RebekahDSK\Desktop\gwu-arl-data-pt-09-2020-u-c\02-Homework\04-Python-Pandas\03-Pandas-Project\Mini-Project-Part-1\Resources\2016-FCC-New-Coders-Survey-Data.csv")
coders_df
# Out:
# C:\Users\RebekahDSK\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (21,57) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#         Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0      28.0               0.0             NaN                   NaN
# 1      22.0               0.0             NaN                   NaN
# 2      19.0               0.0             NaN                   NaN
# 3      26.0               0.0             NaN                   NaN
# 4      20.0               0.0             NaN                   NaN
# ...     ...               ...             ...                   ...
# 15615  39.0               0.0             NaN                   NaN
# 15616  27.0               0.0             NaN                   NaN
# 15617  37.0               0.0             NaN                   NaN
# ...

# %%
# Inspect all columns
coders_df.columns
# Out:
# Index(['Age', 'AttendedBootcamp', 'BootcampFinish', 'BootcampFullJobAfter',
#        'BootcampLoanYesNo', 'BootcampMonthsAgo', 'BootcampName',
#        'BootcampPostSalary', 'BootcampRecommend', 'ChildrenNumber',
#        ...
#        'ResourceSoloLearn', 'ResourceStackOverflow', 'ResourceTreehouse',
#        'ResourceUdacity', 'ResourceUdemy', 'ResourceW3Schools',
#        'ResourceYouTube', 'SchoolDegree', 'SchoolMajor', 'StudentDebtOwe'],
#       dtype='object', length=113)

# %%
coders_df.dtypes
# Out:
# Age                     float64
# AttendedBootcamp        float64
# BootcampFinish          float64
# BootcampFullJobAfter    float64
# BootcampLoanYesNo       float64
#                          ...
# ResourceW3Schools       float64
# ResourceYouTube         float64
# SchoolDegree             object
# SchoolMajor              object
# StudentDebtOwe          float64
# Length: 113, dtype: object

# %%
# Extract only columns 0, 1, 2, 3, 4, 7, 8, 9, 10,11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111
Extracted_coders_df = coders_df.iloc[:,[0, 1, 2, 3, 4, 7, 8, 9, 10,11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111]]
Extracted_coders_df
# Out:
#         Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0      28.0               0.0             NaN                   NaN
# 1      22.0               0.0             NaN                   NaN
# 2      19.0               0.0             NaN                   NaN
# 3      26.0               0.0             NaN                   NaN
# 4      20.0               0.0             NaN                   NaN
# ...     ...               ...             ...                   ...
# 15615  39.0               0.0             NaN                   NaN
# 15616  27.0               0.0             NaN                   NaN
# 15617  37.0               0.0             NaN                   NaN
# 15618  26.0               0.0             NaN                   NaN
# 15619  22.0               0.0             NaN                   NaN
#
#        BootcampLoanYesNo  BootcampPostSalary  BootcampRecommend  \
# 0                    NaN                 NaN                NaN
# ...

# %%
Extracted_coders_df["AttendedBootcamp"].value_counts()
# Out:
# 0.0    14427
# 1.0      953
# Name: AttendedBootcamp, dtype: int64

# %%
# Change '0' to 'No' and '1' to 'Yes'
Extracted_coders_df['AttendedBootcamp'] = Extracted_coders_df['AttendedBootcamp'].replace({0: "No", 1: "Yes"})
Extracted_coders_df.head()
# Out:
# <ipython-input-60-16af2cd1ff28>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Extracted_coders_df['AttendedBootcamp'] = Extracted_coders_df['AttendedBootcamp'].replace({0: "No", 1: "Yes"})
#     Age AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0  28.0               No             NaN                   NaN
# 1  22.0               No             NaN                   NaN
# 2  19.0               No             NaN                   NaN
# 3  26.0               No             NaN                   NaN
# 4  20.0               No             NaN                   NaN
#
#    BootcampLoanYesNo  BootcampPostSalary  BootcampRecommend  ChildrenNumber  \
# 0                NaN                 NaN                NaN             NaN
# ...

# %%
# Calculate total number of respondents in survey
Extracted_coders_df["AttendedBootcamp"].value_counts()
# Out:
# No     14427
# Yes      953
# Name: AttendedBootcamp, dtype: int64

# %%
# Extract rows corresponding only to people who attended a bootcamp
attended_bootcamp = Extracted_coders_df.loc[Extracted_coders_df["AttendedBootcamp"] == "Yes"]
attended_bootcamp.head(3)
# Out:
#       Age AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 93   32.0              Yes             1.0                   0.0
# 97   26.0              Yes             1.0                   1.0
# 130  41.0              Yes             1.0                   1.0
#
#      BootcampLoanYesNo  BootcampPostSalary  BootcampRecommend  ChildrenNumber  \
# 93                 0.0                 NaN                0.0             NaN
# 97                 0.0             45000.0                0.0             NaN
# 130                1.0             75000.0                1.0             3.0
#
#                     CityPopulation  CodeEventBootcamp  \
# 93   between 100,000 and 1 million                NaN
# 97             more than 1 million                NaN
# 130              less than 100,000                NaN
#
#                   CountryLive                        EmploymentField  \
# 93   United States of America  arts, entertainment, sports, or media
# ...

# %%
# Calculate average age of attendees
# Calculate how many people attended a bootcamp
# Calculate how many attendees hold degrees
# Count number of attendees who self-identify as male; female; or are of non-binary gender identification
# Calculate percentage of respondents who attended a bootcamp
# Calculate percentage of respondents belonging to each gender
# Calculate percentage of attendees with a school degree
# Calculate average post-bootcamp salary

# %%
# Calculate the average age of attendees
average_age = attended_bootcamp["Age"].mean()
average_age
# Out:
# 31.066014669926652

# %%
# Calculate how many people attended a bootcamp
attendance = attended_bootcamp["AttendedBootcamp"].value_counts()
attendance
# Out:
# Yes    953
# Name: AttendedBootcamp, dtype: int64

# %%
# Calculate how many attendees hold degrees
unique_degrees = (attended_bootcamp["SchoolDegree"].value_counts())
unique_degrees
# Out:
# bachelor's degree                           462
# some college credit, no degree              116
# master's degree (non-professional)           96
# professional degree (MBA, MD, JD, etc.)      39
# high school diploma or equivalent (GED)      38
# associate's degree                           32
# trade, technical, or vocational training     24
# some high school                             10
# Ph.D.                                         8
# no high school (secondary school)             7
# Name: SchoolDegree, dtype: int64

# %%
# Assign all genders under one variable
BoyGirlOther = Extracted_coders_df.groupby('Gender')
BoyGirlOther

# %%
# Isolate Males
Male_Attendees = BoyGirlOther.get_group('male')
Male_Attendees.head(5)
# Out:
#     Age AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0  28.0               No             NaN                   NaN
# 1  22.0               No             NaN                   NaN
# 2  19.0               No             NaN                   NaN
# 5  34.0               No             NaN                   NaN
# 6  23.0               No             NaN                   NaN
#
#    BootcampLoanYesNo  BootcampPostSalary  BootcampRecommend  ChildrenNumber  \
# 0                NaN                 NaN                NaN             NaN
# 1                NaN                 NaN                NaN             NaN
# 2                NaN                 NaN                NaN             NaN
# 5                NaN                 NaN                NaN             NaN
# 6                NaN                 NaN                NaN             NaN
#
#                   CityPopulation  CodeEventBootcamp               CountryLive  \
# ...

# %%
# Isolate Females
Female_Attendees = BoyGirlOther.get_group('female')
Female_Attendees.head(1)
# Out:
#     Age AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 3  26.0               No             NaN                   NaN
#
#    BootcampLoanYesNo  BootcampPostSalary  BootcampRecommend  ChildrenNumber  \
# 3                NaN                 NaN                NaN             NaN
#
#         CityPopulation  CodeEventBootcamp               CountryLive  \
# 3  more than 1 million                NaN  United States of America
#
#                          EmploymentField    EmploymentStatus  Gender  \
# 3  arts, entertainment, sports, or media  Employed for wages  female
#
#    HasChildren  HoursLearning   Income            JobRoleInterest  \
# 3          NaN           20.0  43000.0    Front-End Web Developer
#
#         SchoolDegree              SchoolMajor
# 3  bachelor's degree  Cinematography And Film

# %%
# Isolate GenderQueer
GenderQueer_Attendees = BoyGirlOther.get_group('genderqueer')
GenderQueer_Attendees.head(1)
# Out:
#       Age AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 315  31.0              Yes             1.0                   0.0
#
#      BootcampLoanYesNo  BootcampPostSalary  BootcampRecommend  ChildrenNumber  \
# 315                0.0                 NaN                0.0             NaN
#
#                     CityPopulation  CodeEventBootcamp  \
# 315  between 100,000 and 1 million                NaN
#
#                   CountryLive       EmploymentField          EmploymentStatus  \
# 315  United States of America  software development  Self-employed freelancer
#
#           Gender  HasChildren  HoursLearning   Income  \
# 315  genderqueer          NaN           20.0  35000.0
#
#                 JobRoleInterest       SchoolDegree     SchoolMajor
# 315    User Experience Designer  bachelor's degree  Communications

# %%
# Isolate Trans
Trans_Attendees = BoyGirlOther.get_group('trans')
Trans_Attendees.head(1)
# Out:
#       Age AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 484  45.0               No             NaN                   NaN
#
#      BootcampLoanYesNo  BootcampPostSalary  BootcampRecommend  ChildrenNumber  \
# 484                NaN                 NaN                NaN             NaN
#
#                     CityPopulation  CodeEventBootcamp  \
# 484  between 100,000 and 1 million                NaN
#
#                   CountryLive              EmploymentField  \
# 484  United States of America  software development and IT
#
#        EmploymentStatus Gender  HasChildren  HoursLearning   Income  \
# 484  Employed for wages  trans          NaN           15.0  75000.0
#
#     JobRoleInterest SchoolDegree SchoolMajor
# 484             NaN        Ph.D.   Education

# %%
# Isolate Agender
Agender_Attendees = BoyGirlOther.get_group('agender')
Agender_Attendees.head(1)
# Out:
#       Age AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 475  34.0               No             NaN                   NaN
#
#      BootcampLoanYesNo  BootcampPostSalary  BootcampRecommend  ChildrenNumber  \
# 475                NaN                 NaN                NaN             1.0
#
#                     CityPopulation  CodeEventBootcamp  \
# 475  between 100,000 and 1 million                NaN
#
#                   CountryLive EmploymentField          EmploymentStatus  \
# 475  United States of America     health care  Self-employed freelancer
#
#       Gender  HasChildren  HoursLearning   Income JobRoleInterest  \
# 475  agender          1.0            5.0  20000.0             NaN
#
#                        SchoolDegree SchoolMajor
# 475  some college credit, no degree         NaN

# %%
# Total number of genders
Total_Genders = Male_Attendees + Female_Attendees + GenderQueer_Attendees + Trans_Attendees + Agender_Attendees
Total_Genders
# Out:
#        Age AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0      NaN              NaN             NaN                   NaN
# 1      NaN              NaN             NaN                   NaN
# 2      NaN              NaN             NaN                   NaN
# 3      NaN              NaN             NaN                   NaN
# 4      NaN              NaN             NaN                   NaN
# ...    ...              ...             ...                   ...
# 15615  NaN              NaN             NaN                   NaN
# 15616  NaN              NaN             NaN                   NaN
# 15617  NaN              NaN             NaN                   NaN
# 15618  NaN              NaN             NaN                   NaN
# 15619  NaN              NaN             NaN                   NaN
#
#        BootcampLoanYesNo  BootcampPostSalary  BootcampRecommend  \
# 0                    NaN                 NaN                NaN
# ...

# %%
# Calculate the number of attendees who self-identify as MALE, FEMALE, GENDERQUEER, TRANS, AGENDER
gender = (attended_bootcamp["Gender"].value_counts())
gender
# Out:
# male           496
# female         326
# genderqueer      6
# trans            3
# agender          2
# Name: Gender, dtype: int64

# %%
# Calculate the percentage of respondents who attended a bootcamp

# %%
# Calculate the percentage of respondents belonging to each gender

# %%
# Calculate the percentage of attendees with a school degree

# %%
# Calculate average post-bootcamp salary

# %%
# Create a new table consolodating above calculations
Dictionary = {"Average Age":[average_age], "Male": [496], "Female": [326], "Gender/Queer": [6] }
Analysis = pd.DataFrame.from_dict(Dictionary, orient='columns')
Analysis
# Out:
#    Average Age  Male  Female  Gender/Queer
# 0    31.066015   496     326             6

# %%
# Improve formatting before outputting spreadsheet

# %%
# Export to Excel
